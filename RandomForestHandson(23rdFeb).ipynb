# %% [markdown]
# <a href="https://colab.research.google.com/github/SantoshMahara/Random_forest-Projects/blob/main/RandomForestHandson(23rdFeb).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Random Forest Handson

# %%
#churn: leaving / moving to another supplier

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('customer_churn.csv')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# plot a graph depicting how many total customers have churned and how many have not

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns=['customerID'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
col_list=[]
for col in df.columns:
  if((df[col].dtype=='object') & (col !='Churn')):
    col_list.append(col)

print(col_list)
# Out:
# ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'TotalCharges']

# %%
from sklearn.preprocessing import LabelEncoder

lencode= LabelEncoder()

for i in col_list:
  df[i] = lencode.fit_transform(df[i])

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
df.tenure.unique()
# Out:
# array([ 1, 34,  2, 45,  8, 22, 10, 28, 62, 13, 16, 58, 49, 25, 69, 52, 71,
#        21, 12, 30, 47, 72, 17, 27,  5, 46, 11, 70, 63, 43, 15, 60, 18, 66,
#         9,  3, 31, 50, 64, 56,  7, 42, 35, 48, 29, 65, 38, 68, 32, 55, 37,
#        36, 41,  6,  4, 33, 67, 23, 57, 61, 14, 20, 53, 40, 59, 24, 44, 19,
#        54, 51, 26,  0, 39])

# %%
# #checking Outliers
# for col_name in col_list:
#   if (df[col_name].dtypes=='int64' or df[col_name].dtypes=='float64'):
#     sns.boxplot(df[col_name])
#     plt.xlabel(col_name)
#     plt.ylabel('values')
#     plt.show()

# for col_name in col_list:
#     if(df[col_name].dtypes=='int64' or df[col_name].dtypes=='float64'):
#         plt.boxplot(df[col_name])
#         plt.xlabel(col_name)
#         plt.ylabel('values')
#         plt.show()

# %%
X = df.iloc[:, :-1]
Y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test= train_test_split(X, Y, test_size=0.25, random_state=0)

# %%
x_train
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 3296       0              0        0           0      24             1
# 6397       1              1        0           0      54             1
# 6043       1              0        0           0       3             0
# 5309       0              0        1           0      61             1
# 3000       1              0        0           0      12             1
# ...      ...            ...      ...         ...     ...           ...
# 4931       1              0        1           0      15             1
# 3264       0              0        0           1      10             1
# 1653       1              0        1           0      58             1
# 2607       1              1        0           0       1             1
# 2732       0              0        0           1       4             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
x_test
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 2200       0              0        0           0      19             1
# 4627       1              0        0           0      60             1
# 3225       0              0        0           0      13             1
# 2828       1              0        0           0       1             1
# 3768       0              0        1           0      55             1
# ...      ...            ...      ...         ...     ...           ...
# 3184       0              0        1           0      71             1
# 2551       0              0        0           0      12             1
# 5735       0              0        1           1      48             1
# 5096       1              0        1           1      71             1
# 450        0              0        0           0      64             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
y_train
# Out:
# 3296     No
# 6397     No
# 6043    Yes
# 5309     No
# 3000    Yes
#        ...
# 4931     No
# 3264     No
# 1653     No
# 2607    Yes
# 2732     No
# Name: Churn, Length: 5282, dtype: object

# %%
y_test
# Out:
# 2200    No
# 4627    No
# 3225    No
# 2828    No
# 3768    No
#         ..
# 3184    No
# 2551    No
# 5735    No
# 5096    No
# 450     No
# Name: Churn, Length: 1761, dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier(n_estimators=100)
model_rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model_rf.predict(x_test)

# %%
y_pred
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
y_test
# Out:
# 2200    No
# 4627    No
# 3225    No
# 2828    No
# 3768    No
#         ..
# 3184    No
# 2551    No
# 5735    No
# 5096    No
# 450     No
# Name: Churn, Length: 1761, dtype: object

# %%
from sklearn.metrics import *

# %%
accuracy_score(y_pred, y_test)
# Out:
# 0.7904599659284497

# %%
confusion_matrix(y_pred, y_test)
# Out:
# array([[1158,  229],
#        [ 140,  234]])

# %%
#0.7881 ->200
#0.7825 ->100  ->best model
#0.7762 ->50

# %% [markdown]
# Checking for different n_estimator values

# %%
n_list = [1,50,100,200,300,400,500]
n_accu=[]

for i in n_list:
  model= RandomForestClassifier(n_estimators=i)
  model.fit(x_train,y_train)
  y_pred= model.predict(x_test)
  acc= accuracy_score(y_pred, y_test)
  n_accu.append(acc)

# %%
n_accu
# Out:
# [0.7319704713231119,
#  0.7853492333901193,
#  0.7921635434412265,
#  0.7864849517319704,
#  0.7887563884156729,
#  0.7904599659284497,
#  0.7853492333901193]

# %%
#100 estimator are best for my model
